# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

df = pd.read_csv("../metadata.csv")
df.head()
# Out:
#          Response_ID                                   file_name   Age  \
# 0  R_1KvCEEGNThnpnzy      audio_data/Names/R_1KvCEEGNThnpnzy.wav  24.0
# 1  R_1KvCEEGNThnpnzy  audio_data/Addresses/R_1KvCEEGNThnpnzy.wav  24.0
# 2  R_1KvCEEGNThnpnzy    audio_data/Numbers/R_1KvCEEGNThnpnzy.wav  24.0
# 3  R_3nAeHdtYMOFbRQJ      audio_data/Names/R_3nAeHdtYMOFbRQJ.wav  21.0
# 4  R_3nAeHdtYMOFbRQJ  audio_data/Addresses/R_3nAeHdtYMOFbRQJ.wav  21.0
#
#    Gender Nationality Native Language  \
# 0  Female      Indian         Marathi
# 1  Female      Indian         Marathi
# 2  Female      Indian         Marathi
# 3  Female      Indian           Hindi
# 4  Female      Indian           Hindi
#
#                           Familiarity with English  \
# 0  Educated in English, but not my native language
# 1  Educated in English, but not my native language
# 2  Educated in English, but not my native language
# 3  Educated in English, but not my native language
# 4  Educated in English, but not my native language
#
#    Accent Strength (Self reported)         Difficulties Recording Machine  \
# 0                                5  About half the time    Phone Recorder
# 1                                5  About half the time    Phone Recorder
# 2                                5  About half the time    Phone Recorder
# 3                                3            Sometimes    Phone Recorder
# 4                                3            Sometimes    Phone Recorder
#
#              Name      Number              Address  Duration (secs)
# 0  Saffron Robles  8885112931    48 Ridge Road 407              278
# 1  Saffron Robles  8885112931    48 Ridge Road 407              278
# 2  Saffron Robles  8885112931    48 Ridge Road 407              278
# 3         Anannya  9196856019  7204, McQueen Drive              542
# 4         Anannya  9196856019  7204, McQueen Drive              542

# %%
df.describe()
# Out:
#               Age  Accent Strength (Self reported)        Number  \
# count  207.000000                       210.000000  2.100000e+02
# mean    24.391304                         4.957143  5.122851e+09
# std      3.336547                         2.469541  3.200174e+09
# min     20.000000                         0.000000  7.000000e+00
# 25%     23.000000                         3.000000  2.288775e+09
# 50%     24.000000                         5.000000  5.214430e+09
# 75%     25.000000                         7.000000  8.178070e+09
# max     39.000000                         9.000000  9.898006e+09
#
#        Duration (secs)
# count       210.000000
# mean        354.542857
# std         215.085697
# min         110.000000
# 25%         195.000000
# 50%         285.000000
# 75%         489.000000
# max         984.000000

# %%
# 1. Age Distribution (Bar Chart)
plt.figure(figsize=(8, 5))
sns.histplot(df['Age'], kde=False, color='skyblue', bins=5)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# 2. Gender Distribution (Donut Chart)
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(7, 7))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel"))
plt.title('Gender Distribution')
plt.gca().set_aspect('equal')
plt.show()

# %%
# 3. Nationality Distribution (Bar Chart)
plt.figure(figsize=(8, 5))
sns.countplot(y=df['Nationality'], palette='coolwarm')
plt.title('Nationality Distribution')
plt.gca().set_aspect('equal')
plt.show()
# Out:
# C:\Users\saksh\AppData\Local\Temp\ipykernel_56720\1499609431.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['Nationality'], palette='coolwarm')

# %%
# Native Language Distribution (Bar Chart)
plt.figure(figsize=(8, 5))
sns.countplot(y=df['Native Language'], palette='coolwarm')
plt.title('Native Language Distribution')
plt.gca().set_aspect('equal')
plt.show()
# Out:
# C:\Users\saksh\AppData\Local\Temp\ipykernel_37340\3268139136.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['Native Language'], palette='coolwarm')

# %%
# Familiarity with English (Bar Chart)
plt.figure(figsize=(8, 5))
sns.countplot(y=df['Familiarity with English'], palette='coolwarm')
plt.title('Familiarity with English')
plt.xlabel('Count')
plt.ylabel('Familiarity Level')
plt.show()
# Out:
# C:\Users\saksh\AppData\Local\Temp\ipykernel_37340\1451553406.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['Familiarity with English'], palette='coolwarm')

# %%
df['Familiarity with English'].value_counts()
# Out:
# Familiarity with English
# Educated in English, but not my native language    165
# Native speaker                                      24
# Basic knowledge; not fluent                         21
# Name: count, dtype: int64

# %%
# Duration Distribution (Histogram)
plt.figure(figsize=(8, 5))
sns.histplot(df['Duration (secs)'], kde=False, color='coral', bins=10)
plt.title('Recording Duration Distribution')
plt.xlabel('Duration (seconds)')
plt.ylabel('Count')
plt.show()
